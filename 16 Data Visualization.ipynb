# %% [markdown]
# ##### Import the libraries

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
x = np.array([2,6,14,19,33,39,41,59,60,76])
y = np.array([10,13,21,22,47,37,58,71,82,88])
z = np.array([67,65,54,49,44,41,30,27,32,17])
p = np.array([45,66,54,26,45,67,44,57,22,47])

# %% [markdown]
# ##### Line Plot

# %%
plt.plot(x, y)

# %%
plt.plot(x, z)

# %%
plt.plot(x, p)

# %%
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.plot(x, y)

# %%
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
# markers: .  o  *  D  <  >  ^  v  
# ls-    :  --   -.
plt.plot(x, y, color='purple', marker='o', ms=10, mfc='yellow', lw=3, ls=':')

# %%
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.plot(x, y, color = 'r', label = '2022')
plt.plot(x, z, color = 'g', label = '2023')
plt.legend()

# %%
plt.subplot(1,2,1)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, y, color ='b')

plt.subplot(1,2,2)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, z, color='magenta')

# %%
plt.subplot(2,1,1)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, y, color ='b')

plt.subplot(2,1,2)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, z, color='magenta')

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, y, color ='b')

plt.subplot(1,2,2)
plt.title('2022')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,20))
plt.yticks(range(0,91,20))
plt.plot(x, z, color='magenta')

# %%
plt.subplot(2,2,1)
plt.plot(x, y)
plt.subplot(1,2,2)
plt.plot(x, z)
plt.subplot(2,2,3)
plt.plot(x, p)

# %%
sal = pd.read_csv('Salary_Data.csv')

# %%
plt.plot(sal['YearsExperience'], sal['Salary'])

# %% [markdown]
# ##### Scatter Plot

# %%
plt.title('My first plot')
plt.xlabel('First Value')
plt.ylabel('Second Value')
plt.grid()
plt.xlim(0,90)
plt.ylim(0,90)
plt.xticks(range(0,91,5))
plt.yticks(range(0,91,5))
plt.scatter(x, y)

# %%
from sklearn.datasets import load_iris

# %%
iris = load_iris()

# %%
x = iris.data
y = iris.target

# %%
iris.target_names
# Out:
# array(['setosa', 'versicolor', 'virginica'], dtype='<U10')

# %%
plt.figure(figsize=(16,9))
plt.subplot(2,2,1)
plt.title('Sepal Length vs Sepal Width')
plt.xlabel('Sepal Length')
plt.ylabel('Sepal Width')
plt.scatter(x[:,0], x[:,1], c=  y)

plt.subplot(2,2,2)
plt.title('Sepal Width vs. Petal Length')
plt.title('Sepal Width')
plt.xlabel('Sepal Width')
plt.ylabel('Petal Length')
plt.scatter(x[:,1], x[:,2], c=  y)

plt.subplot(2,2,3)
plt.title('Petal Length vs Petal Width')
plt.xlabel('Petal Length')
plt.ylabel('Petal Width')
plt.scatter(x[:,2], x[:,3], c=  y)

plt.subplot(2,2,4)
plt.title('Sepal Length vs Petal Length')
plt.xlabel('Sepal Length')
plt.ylabel('Petal Length')
plt.scatter(x[:,0], x[:,2], c=  y)

# %% [markdown]
# ##### Bar plot

# %%
langs = ['C', 'C++', 'Java', 'Python', 'PHP', 'JavaScript']
studs = [[67, 92, 104, 168, 122, 150], [45,87,56,105,100,106]]

# %%
plt.title('Total Enrollment')
plt.grid()
plt.xlabel('Courses')
plt.ylabel('Total Students')
plt.bar(langs, studs[0], width=0.25)
plt.bar(langs, studs[1], width = 0.25)
# Out:
# <BarContainer object of 6 artists>

# %%
plt.title('Total Enrollment')
plt.grid()
plt.ylabel('Courses')
plt.xlabel('Total Students')
plt.barh(langs, studs[0], color = 'navy')
# Out:
# <BarContainer object of 6 artists>

# %%
stu = pd.read_csv('student.csv')

# %%
stu
# Out:
#    roll     name class  marks  age
# 0     1     anil    TE  56.77   22
# 1     2     amit    TE  59.77   21
# 2     3   aniket    BE  76.88   19
# 3     4  ajinkya    TE  69.66   20
# 4     5     asha    TE  63.28   20
# 5     6   ayesha    BE  49.55   20
# 6     7     amar    BE  65.34   19
# 7     8    amita    BE  68.33   23
# 8     9     amol    TE  56.75   20
# 9    10    anmol    BE  78.66   21

# %%
x_marks = range(10)  # Positions for marks bars
x_age = [i + 0.3 for i in x_marks]  # Positions for age bars (shifted right)

plt.figure(figsize=(10, 6))  
plt.xticks(range(10))
plt.bar(x_marks, stu["marks"], width=0.4, label="Marks", color='skyblue')
plt.bar(x_age, stu["age"], width=0.4, label="Age", color='lightgreen')
plt.legend()

# %% [markdown]
# ##### Pie Chart

# %%
plt.title('% enrollment')
plt.pie(studs[0], labels=langs, autopct='%2.2f%%', 
        shadow=True, radius=1.5);

# %%
sna = pd.read_csv('Social_Network_Ads.csv')

# %%
sna
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
sna['Gender'].value_counts()
# Out:
# Gender
# Female    204
# Male      196
# Name: count, dtype: int64

# %%
plt.pie(sna['Gender'].value_counts(), 
        labels=sna['Gender'].value_counts().index, autopct='%2.2f%%');

# %% [markdown]
# ##### Histogram

# %%
plt.xticks(range(10,61,10))
plt.yticks(range(0,141,10))
plt.hist(sna['Age'], bins=range(10,61,10), color='maroon');

# %%
plt.figure(figsize=(16,9))
plt.subplot(1,2,1)
plt.xticks(range(10,61,10))
plt.yticks(range(0,141,10))
plt.hist(sna['Age'], bins=range(10,61,10), color='maroon');

plt.subplot(1,2,2)
plt.xticks(range(10000,150001,15000))
plt.yticks(range(0,141,10))
plt.hist(sna['EstimatedSalary'], bins=range(10000,150001,15000), color='yellow');

# %% [markdown]
# ##### KDE Plot

# %%
sns.kdeplot(sna['Age'], color='b')
# Out:
# <Axes: xlabel='Age', ylabel='Density'>

# %%
sns.kdeplot(sna['EstimatedSalary'], color='r')
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Density'>

# %%
sns.displot(sna['EstimatedSalary'], color='r')

# %%
sns.histplot(sna['EstimatedSalary'], color='g', kde=True)
# Out:
# <Axes: xlabel='EstimatedSalary', ylabel='Count'>

# %% [markdown]
# ##### Box plot

# %%
plt.boxplot(sna['Age']);

# %%
iris = sns.load_dataset('iris')

# %%
iris
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
sns.boxplot(iris)
# Out:
# <Axes: >

# %%
sns.boxplot(data=iris)
# Out:
# <Axes: >

# %%
iris.plot()
# Out:
# <Axes: >

# %%
iris.plot.scatter(x='sepal_length', y='petal_length')
# Out:
# <Axes: xlabel='sepal_length', ylabel='petal_length'>

# %%
sna['Purchased'].value_counts().plot.pie(autopct='%2.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
stu.plot.bar()
# Out:
# <Axes: >

# %%
stu.plot.box()
# Out:
# <Axes: >

# %%
tasks = ["Task A", "Task B", "Task C", "Task D"]
start_dates = [0, 2, 5, 8]  # Start days (relative to some reference)
durations = [3, 4, 4, 2]    # Durations in days

fig, ax = plt.subplots(figsize=(10, 6))

ax.set_ylabel("Tasks")
ax.set_yticks(range(len(tasks)))
ax.set_yticklabels(tasks)

ax.invert_yaxis()
ax.set_xlabel("Days")

# Create Gantt bars
for i, task in enumerate(tasks):
  start_day = start_dates[i]
  duration = durations[i]
  ax.barh(i, duration, left=start_day, color='skyblue')
  ax.text(start_day + duration/2, i, task, ha='center', va='center')

ax.set_xlim(min(start_dates) - 1, max(start_dates + durations) + 2)
ax.grid(axis='x', linestyle='--')
ax.set_title("Gantt Chart")
ax.set_xticks(range(0,11))
plt.show()

# %% [markdown]
# ##### Jointplot

# %%
sns.jointplot(x='Age', y = 'EstimatedSalary', 
              data = sna, hue = 'Purchased', palette='rocket')

# %% [markdown]
# ##### Pairplot

# %%
sns.pairplot(iris)

# %%
sns.pairplot(iris, hue = 'species')
