# %% [markdown]
# #### Theoritical Probability

# %%
def coin_flip_probability():
  """Calculates the probability of heads in a fair coin flip."""
  heads_probability = 1 / 2
  return heads_probability

def rolling_dice_probability(number):
  """Calculates the probability of rolling a specific number on a fair die."""
  if number not in range(1, 7):
    raise ValueError("Number must be between 1 and 6")
  probability = 1 / 6
  return probability

# %%
# Example usage
coin_flip_result = coin_flip_probability()
dice_roll_result = rolling_dice_probability(6)

print("Probability of heads in a coin flip:", coin_flip_result)
print("Probability of rolling a 4 on a die:", dice_roll_result)
# Out:
# Probability of heads in a coin flip: 0.5
# Probability of rolling a 4 on a die: 0.16666666666666666

# %% [markdown]
# #### Experimental Probability

# %%
import random
import pandas as pd

# %%
def simulate_coin_flips(num_flips):
  """Simulates coin flips and returns a list of results (heads or tails)"""
  results = []
  for _ in range(num_flips):
    flip = random.choice(["heads", "tails"])
    results.append(flip)
  return results

# %%
pd.Series(simulate_coin_flips(100)).value_counts()
# Out:
# tails    53
# heads    47
# Name: count, dtype: int64

# %%
def calculate_experimental_probability(results, event):
  """Calculates the experimental probability of a specific event (heads or tails)"""
  event_count = results.count(event)
  total_flips = len(results)
  probability = event_count / total_flips
  return probability

# %%
# Example usage
num_flips = 1000
simulation_results = simulate_coin_flips(num_flips)

heads_probability = calculate_experimental_probability(simulation_results, "heads")
tails_probability = calculate_experimental_probability(simulation_results, "tails")

print(f"Number of flips: {num_flips}")
print(f"Heads probability: {heads_probability:.4f}")
print(f"Tails probability: {tails_probability:.4f}")
# Out:
# Number of flips: 1000
# Heads probability: 0.5210
# Tails probability: 0.4790

# %% [markdown]
# ##### Discrete Probability

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
ages = [21,23,22,23,23,21,20,19,21,21,21,22,23,21,20,19,21,23,21,21]

# %%
plt.hist(ages, bins=[18,19,20,21,22,23,24]);

# %%
import seaborn as sns

# %%
sns.kdeplot(ages)
# Out:
# <Axes: ylabel='Density'>

# %%
cars = []
zero = ['0 cars' for x in range(30)] 
one = ['1 car' for x in range(130)] 
two = ['2 cars' for x in range(700)]
three = ['3 cars' for x in range(100)]
four = ['4 cars+' for x in range(40)]
cars.extend(zero); cars.extend(one); cars.extend(two); cars.extend(three);
cars.extend(four);

# %%
len(cars)
# Out:
# 1000

# %%
plt.xticks(range(6))
plt.hist(cars, bins=['0 cars', '1 car','2 cars','3 cars','4 cars+']);

# %%
sns.kdeplot(pd.Series(cars).value_counts())
# Out:
# <Axes: xlabel='count', ylabel='Density'>

# %%
temp = [np.random.randint(20,40) for x in range(1000)]

# %%
sns.kdeplot(temp)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# ##### Gaussian Distribution

# %%
data = np.random.normal(0, 1, 1000)

# %%
data
# Out:
# array([-1.66033568e+00,  1.82496495e+00, -6.04501148e-01,  1.65264602e+00,
#        -1.64446601e+00, -4.81052679e-01, -1.58319053e+00, -1.29906146e+00,
#         2.13127540e-01, -4.91312469e-01,  1.10621516e+00, -1.53977742e+00,
#        -1.05204118e+00, -2.14601103e-01, -2.83099924e-01,  9.66161237e-01,
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# #### Binomial Distribution

# %%
# Calculate the probability of getting 7 heads in 10 flips of a coin.

# %%
p = 0.5 # Probability of heads
n = 10 # Number of experiments

# %%
probability = np.random.binomial(n, p)

# %%
print(probability/7)
# Out:
# 0.42857142857142855

# %% [markdown]
# #### Poisson Probability

# %%
# Calculate the probability of getting 5 customers in a store in one hour, 
# given that the average number of customers is 5 per hour.

# %%
lamb = 5 # Mean number of customers in one hour

# %%
probability = np.random.poisson(lamb)

# %%
print(probability/10)
# Out:
# 0.3

# %% [markdown]
# #### Bayes Theorem and Classification

# %%
# Dataset: ingredients.csv
# Location: https://mitu.co.in/dataset

# %%
df = pd.read_csv('ingredients.csv')

# %%
df
# Out:
#     sweetness  crunchiness ingredients      class
# 0           1            1      cheese    protein
# 1           3            1        fish    protein
# 2           2            2      shrimp    protein
# 3           1            4       bacon    protein
# 4           3            5        nuts    protein
# 5           1            9     lettuce  vegetable
# 6           2            8    cucumber  vegetable
# 7           3            7  green bean  vegetable
# 8           5           10      carrot  vegetable
# 9           3           10      celery  vegetable
# 10         10            9       apple      fruit
# 11         10            7        pear      fruit
# 12          9            5       grape      fruit
# 13          9            2      orange      fruit
# 14         10            2      banana      fruit

# %%
x = df[['sweetness','crunchiness']]
y = df['class']

# %%
# import the class
from sklearn.naive_bayes import GaussianNB

# %%
# create the object
nb = GaussianNB()

# %%
# ttrain the algorithm
nb.fit(x, y)
# Out:
# GaussianNB()

# %%
tomato = [[6, 5]]

# %%
y.value_counts()
# Out:
# class
# protein      5
# vegetable    5
# fruit        5
# Name: count, dtype: int64

# %%
nb.predict_proba(tomato) * 100
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array([[7.52797491e-07, 5.67640640e+00, 9.43235928e+01]])

# %%
nb.predict(tomato)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# array(['vegetable'], dtype='<U9')

# %%
nb.classes_
# Out:
# array(['fruit', 'protein', 'vegetable'], dtype='<U9')

# %%
sum(nb.predict_proba(tomato)[0] * 100)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:465: UserWarning: X does not have valid feature names, but GaussianNB was fitted with feature names
#   warnings.warn(
# 99.99999999999999

# %%
# Dataset: Social_Network_Ads.csv
# Location: https://mitu.co.in/dataset

# %%
df = pd.read_csv('Social_Network_Ads.csv')

# %%
df
# Out:
#       User ID  Gender   Age  EstimatedSalary  Purchased
# 0    15624510    Male  19.0          19000.0          0
# 1    15810944    Male  35.0          20000.0          0
# 2    15668575  Female  26.0          43000.0          0
# 3    15603246  Female  27.0          57000.0          0
# 4    15804002    Male  19.0          76000.0          0
# ..        ...     ...   ...              ...        ...
# 395  15691863  Female  46.0          41000.0          1
# 396  15706071    Male  51.0          23000.0          1
# 397  15654296  Female  50.0          20000.0          1
# 398  15755018    Male  36.0          33000.0          0
# 399  15594041  Female  49.0          36000.0          1
#
# [400 rows x 5 columns]

# %%
x = df[['Age','EstimatedSalary']]
y = df['Purchased']

# %%
y.value_counts()
# Out:
# Purchased
# 0    257
# 1    143
# Name: count, dtype: int64

# %%
nb = GaussianNB()

# %%
nb.fit(x, y)
# Out:
# GaussianNB()

# %%
new = pd.DataFrame({
    'Age': [23,58,43],
    'EstimatedSalary': [45000,134000,78000]
})

# %%
new
# Out:
#    Age  EstimatedSalary
# 0   23            45000
# 1   58           134000
# 2   43            78000

# %%
nb.predict_proba(new)
# Out:
# array([[0.98786913, 0.01213087],
#        [0.00119846, 0.99880154],
#        [0.55903635, 0.44096365]])

# %%
nb.predict(new)
# Out:
# array([0, 1, 0])
